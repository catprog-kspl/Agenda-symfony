# %% [markdown]
# <a href="https://colab.research.google.com/github/catprog-kspl/Agenda-symfony/blob/main/DataCleanHakatonBBVA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas  as pd

# %%
#Load baseDatosClientes
dataBaseClients = pd.read_csv("baseClientesHackaton2022.csv")

# %%
#Load baseDatosUsuarios
dataBaseUsers = pd.read_csv("baseUsuarios.csv")

# %% [markdown]
# # Sección nueva

# %%
#Verify the nulls values
dataClients =  dataBaseClients.isnull()
dataClients
# Out:
#         idCliente  nombre  apellidoPaterno  apellidoMaterno  fechaNacimiento  \
# 0           False   False            False            False            False
# 1           False   False            False            False            False
# 2           False   False            False            False            False
# 3           False   False            False            False            False
# 4           False   False            False            False            False
# ...           ...     ...              ...              ...              ...
# 100005      False   False            False            False            False
# 100006      False   False            False            False            False
# 100007      False   False            False            False            False
# 100008      False   False            False            False            False
# 100009      False   False            False             True            False
#
# ...

# %%
#Verify the nulls values
dataClients =  dataBaseClients.isnull()
dataClients
# Out:
#         idCliente  nombre  apellidoPaterno  apellidoMaterno  fechaNacimiento  \
# 0           False   False            False            False            False
# 1           False   False            False            False            False
# 2           False   False            False            False            False
# 3           False   False            False            False            False
# 4           False   False            False            False            False
# ...           ...     ...              ...              ...              ...
# 100005      False   False            False            False            False
# 100006      False   False            False            False            False
# 100007      False   False            False            False            False
# 100008      False   False            False            False            False
# 100009      False   False            False             True            False
#
# ...

# %%
#Replace the nulls values
dataBaseClientWithData = dataBaseClients.fillna(value="Campo sin informacion")
dataBaseClientWithData
# Out:
#           idCliente            nombre apellidoPaterno        apellidoMaterno  \
# 0       BF000002999            Amelia          Rivero                  Calva
# 1       BF000003000             Abril           Ocaña                 Almeda
# 2       CI000003001  Claudia Carolina          Molina                 Almeda
# 3       BF000003002             Greta         Arteaga              Guarneros
# 4       BF000003003              Enzo     Olavarrieta              Arellanes
# ...             ...               ...             ...                    ...
# 100005  CI000103004            Damián        Martínez                  Calva
# 100006  CI000103005        Igor Mario         Mohamed                 Castro
# 100007  BF000103006          Giovanni          Flores                Ramírez
# 100008  BF000103007           Gabriel        Barragán               Decanini
# 100009  AB000103008        Axel Jorge           Arias  Campo sin informacion
#
# ...

# %%
sumaNulos = dataBaseClientWithData.isnull().sum()
sumaNulos
# Out:
# idCliente          0
# nombre             0
# apellidoPaterno    0
# apellidoMaterno    0
# fechaNacimiento    0
# sexo               0
# segmento           0
# nacionalidad       0
# rfc                0
# tipoID             0
# numeroID           0
# cuenta             0
# email              0
# dtype: int64

# %%
#Create csv
dataClients.to_csv("baseDatos.csv")

# %%
SumaNulosUsuarios = baseDatosUsuarios.isnull().sum()
SumaNulosUsuarios
# Out:
# usuario           0
# auth              0
# nombreCompleto    0
# area              0
# ubicacion         0
# segmento          0
# perfil            0
# dtype: int64

# %%
sumaDuplicados = dataClients.isnull().sum()
sumaDuplicados
# Out:
# idCliente          0
# nombre             0
# apellidoPaterno    0
# apellidoMaterno    0
# fechaNacimiento    0
# sexo               0
# segmento           0
# nacionalidad       0
# rfc                0
# tipoID             0
# numeroID           0
# cuenta             0
# email              0
# dtype: int64

# %%
dataBaseUsers.to_csv("dataBaseUsuarios.csv")
